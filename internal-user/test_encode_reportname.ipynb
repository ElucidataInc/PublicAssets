# %% [markdown]
# # Welcome to Polly Python3 Notebook.

# %%
pip install https://elucidatainc.github.io/PublicAssets/builds/polly-python/tests/testpolly/polly_python-encode_0.2.10-py3-none-any.whl
# Out:
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, http://54.245.179.143:80/
# ...
#      |████████████████████████████████| 113 kB 6.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 134 kB 6.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 297 kB 6.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 510 kB 76.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 50 kB 13.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 15.2 MB 69.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 52 kB 2.6 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 317 kB 77.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 61 kB 16.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 225 kB 81.4 MB/s eta 0:00:01
# ...

# %%
AUTH_TOKEN=(os.environ['POLLY_REFRESH_TOKEN'])
import os
from polly.auth import Polly
from polly.omixatlas import OmixAtlas
Polly.auth(AUTH_TOKEN)
# Out:
# You're currently using an outdated version of polly-python '0.2.10'. Please update using the command 'pip install polly-python==0.2.8' to upgrade to the newest version '0.2.8'

# %%
omixatlas = OmixAtlas()
omixatlas.link_report("geo","GSE100000_GPL17021",7938,"GSE99361@GPL19441#report.html","private")
# Out:
# File Successfully linked to dataset id = GSE100000_GPL17021. The URL for the private access is 'https://polly.elucidata.io/manage/restricted/file?id=7938&path=%2Fprojects%2F7938%2Ffiles%2FGSE99361%2540GPL19441%2523report.html'

# %%
omixatlas.link_report("geo","GSE100000_GPL17021",8108,"report#name.html","private")
# Out:
# File Successfully linked to dataset id = GSE100000_GPL17021. The URL for the private access is 'https://polly.elucidata.io/manage/restricted/file?id=8108&path=%2Fprojects%2F8108%2Ffiles%2Freport%2523name.html'

# %%
omixatlas.fetch_linked_reports("geo","GSE100000_GPL17021")
# Out:
# Not enough permissions for the workspace_id : 10416. Please contact Polly Support.
# Not enough permissions for the workspace_id : 10416. Please contact Polly Support.
# Not enough permissions for the workspace_id : 10416. Please contact Polly Support.
# The workspace path 'GSE137140_GPL21263_report.html' is invalid. Please contact Polly Support.
#                      Added_by           Added_time  \
# 0  vivek.mathpal@elucidata.io  13/03/2023 06:39:28
# 1  vivek.mathpal@elucidata.io  13/03/2023 06:40:24
#
#                                                                                                                                  URL  \
# 0  https://polly.elucidata.io/manage/restricted/file?id=7938&path=%2Fprojects%2F7938%2Ffiles%2FGSE99361%2540GPL19441%2523report.html
# 1                   https://polly.elucidata.io/manage/restricted/file?id=8108&path=%2Fprojects%2F8108%2Ffiles%2Freport%2523name.html
#
#                               Report_id
# ...
