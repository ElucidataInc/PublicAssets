# %%
pip install https://elucidatainc.github.io/PublicAssets/builds/polly-python/tests/testpolly/polly_python-3.1.0-py3-none-any.whl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 kB 5.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: polly-python
#     Found existing installation: polly_python 3.0.0
#     Uninstalling polly_python-3.0.0:
#       Successfully uninstalled polly_python-3.0.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from polly.auth import Polly
from polly.workspaces import Workspaces
API_KEY = ""
Polly.auth(API_KEY, env="testpolly")
w = Workspaces()

# %%
w.create_workspace("new_workspace_8")
# Out:
# INFO:root:Workspace Created !
# {'name': 'new_workspace_8',
#  'description': None,
#  'project_property': {'type': 'workspaces', 'labels': ''},
#  'created_time': '2024-12-19 10:09:50',
#  'last_modified': '2024-12-19 10:09:50',
#  'status': 1,
#  'creator': 1709822253,
#  'organisation': 1,
#  'id': 16612,
#  'tag_names': []}

# %%
w._fetch_workspaces_iteratively()
# Out:
# [{'id': 16612,
#   'name': 'new_workspace_8',
#   'status': 'active',
#   'description': None,
#   'last_modified': '2024-12-19 10:09:50',
#   'tag_names': [],
#   'favourite': False,
#   'watch': False},
#  {'id': 16564,
#   'name': 'mimic_demo_etl',
#   'status': 'active',
#   'description': '',
#   'last_modified': '2024-10-03 04:22:17',
#   'tag_names': [],
#   'favourite': False,
#   'watch': False},
#  {'id': 16560,
#   'name': 'new_workspace_6',
#   'status': 'active',
#   'description': None,
#   'last_modified': '2024-09-16 13:42:42',
#   'tag_names': [],
#   'favourite': False,
#   'watch': False},
#  {'id': 16559,
#   'name': 'new_workspace_6',
#   'status': 'active',
#   'description': None,
#   'last_modified': '2024-09-17 06:18:40',
#   'tag_names': [],
#   'favourite': False,
#   'watch': False},
#  {'id': 16558,
#   'name': 'test11',
#   'status': 'active',
#   'description': 'testing archive',
#   'last_modified': '2024-11-28 10:38:25',
#   'tag_names': [],
# ...

# %%
w.fetch_my_workspaces()
# Out:
#     Workspace_id                     Workspace_name    status  \
# 0          16503                       my_workspace    active
# 1          16612                    new_workspace_8    active
# 2          16558                             test11    active
# 3          16557                           new_test    active
# 4          16564                     mimic_demo_etl    active
# 5          16524                new_test_workspace2    active
# 6          15492  new_workspace_testing_4__Restored    active
# 7          16559                    new_workspace_6    active
# 8          16560                    new_workspace_6    active
# 9          16518                      New_Workspace    active
# 10         14643                     LIB-215_report    active
# 11         16535                    new_workspace_5    active
# 12         16533                new_test_workspace4    active
# 13         16532                new_test_workspace4    active
# ...

# %%
w.list_contents("16503")
# Out:
#                                         file_name       size  \
# 0   Polly Notebook Mon Apr 15 2024 15:29:51.ipynb   29.26 KB
# 1   Polly Notebook Fri Apr 12 2024 14:16:40.ipynb   61.64 KB
# 2   Polly Notebook Wed May 22 2024 19:50:07.ipynb     65.0 B
# 3   Polly Notebook Wed May 29 2024 16:54:35.ipynb     65.0 B
# 4   Polly Notebook Wed May 29 2024 17:19:29.ipynb    26.7 KB
# 5                                      new_folder          -
# 6   Polly Notebook Thu Apr 04 2024 20:10:38.ipynb     65.0 B
# 7   Polly Notebook Thu Apr 04 2024 20:11:56.ipynb    1.27 KB
# 8   Polly Notebook Fri Apr 12 2024 18:14:20.ipynb    577.0 B
# 9   Polly Notebook Mon Apr 15 2024 15:29:21.ipynb     65.0 B
# 10  Polly Notebook Fri Apr 19 2024 09:59:07.ipynb   43.53 KB
# 11  Polly Notebook Wed Aug 21 2024 16:40:30.ipynb   43.53 KB
# 12                                     sample.pdf   18.37 KB
# 13  Polly Notebook Fri Aug 30 2024 13:15:30.ipynb    15.0 KB
# ...

# %%
w.create_copy(16503,"new_folder/",16612)
# Out:
# Workspace_copy started, You will be notified upon completion.
# Copy Operation Successful!

# %%
w.list_contents("16612")
# Out:
#     file_name size last_modified
# 0  new_folder    -             -
