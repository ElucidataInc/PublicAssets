# %% [markdown]
# # Welcome to Polly Python3 Notebook.

# %%
pip install https://elucidatainc.github.io/PublicAssets/builds/polly-python/tests/testpolly/polly_python-0.2.9_fix-py3-none-any.whl
# Out:
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, http://54.245.179.143:80/
# ...
#      |████████████████████████████████| 111 kB 5.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 42 kB 2.1 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 52 kB 2.7 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 7.2 MB 6.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.1 MB 66.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 50 kB 14.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 134 kB 78.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 297 kB 77.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 510 kB 77.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 15.2 MB 68.1 MB/s eta 0:00:01
# ...

# %%
from polly.auth import Polly
from polly.omixatlas import OmixAtlas
AUTH_TOKEN=(os.environ['POLLY_REFRESH_TOKEN'])
Polly.auth(AUTH_TOKEN)
omix = OmixAtlas()
# Out:
# You're currently using an outdated version of polly-python '0.2.9'. Please update using the command 'pip install polly-python==0.2.8' to upgrade to the newest version '0.2.8'

# %%
# omixatlas with h5ad files
dataframe = omix.get_metadata("single_cell_rnaseq_omixatlas","GSE174577_GPL24247","samples_singlecell")
dataframe
# Out:
#         sample_id  platform                      title  \
# 0      GSM5320047  GPL24247  mouse esophageal organoid
# 1      GSM5320047  GPL24247  mouse esophageal organoid
# 2      GSM5320047  GPL24247  mouse esophageal organoid
# 3      GSM5320047  GPL24247  mouse esophageal organoid
# 4      GSM5320047  GPL24247  mouse esophageal organoid
# ...           ...       ...                        ...
# 11531  GSM5320047  GPL24247  mouse esophageal organoid
# 11532  GSM5320047  GPL24247  mouse esophageal organoid
# 11533  GSM5320047  GPL24247  mouse esophageal organoid
# 11534  GSM5320047  GPL24247  mouse esophageal organoid
# 11535  GSM5320047  GPL24247  mouse esophageal organoid
#
#                                      characteristics_ch1  \
# 0      tissue: Mouse esopahgus-derived organoid|||cel...
# 1      tissue: Mouse esopahgus-derived organoid|||cel...
# 2      tissue: Mouse esopahgus-derived organoid|||cel...
# 3      tissue: Mouse esopahgus-derived organoid|||cel...
# ...

# %%
# omixatlas with gct files
dataframe = omix.get_metadata("geo","GSE100000_GPL17021","samples")
dataframe
# Out:
#                                          title taxid_ch1  \
# 0                                 BirA_control     10090
# 1          Fosl1-FB_cloneB11 (high expression)     10090
# 2            Fosl1-FB_cloneC2 (low expression)     10090
# 3                         RNA-seq:BirA_control     10090
# 4  RNA-seq:FB-Fosl1_cloneB11 (high expression)     10090
# 5    RNA-seq:FB-Fosl1_cloneC2 (low expression)     10090
#
#                                  growth_protocol_ch1  \
# 0  Mouse J1 ES cells were maintained in Dulbecco’...
# 1  Mouse J1 ES cells were maintained in Dulbecco’...
# 2  Mouse J1 ES cells were maintained in Dulbecco’...
# 3  Mouse J1 ES cells were maintained in Dulbecco’...
# 4  Mouse J1 ES cells were maintained in Dulbecco’...
# 5  Mouse J1 ES cells were maintained in Dulbecco’...
#
#                                 extract_protocol_ch1  \
# 0  Cells were cross-linked in 1% formaldehyde for...
# 1  Cells were cross-linked in 1% formaldehyde for...
# ...

# %%
dataframe = omix.get_metadata("geo","GSE100000_GPL17021","samples_singlecell")
dataframe
# Out:
# ---------------------------------------------------------------------------
# paramException                            Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 dataframe = omix.get_metadata("geo","GSE100000_GPL17021","samples_singlecell")
#       2 dataframe
#
# File ~/.local/lib/python3.10/site-packages/polly/omixatlas.py:3859, in OmixAtlas.get_metadata(self, repo_key, dataset_id, table_name)
#    3857             index = v2_index.get("gct_col_metadata")
#    3858             if table_name == "samples_singlecell":
# -> 3859                 raise paramException(
#    3860                     title="Param Error",
#    3861                     detail="Argument 'table_name' not valid, please query 'SHOW TABLES IN repo_name' \
#    3862 using query_metadata function and pick the appropriate table name you want the metadata \
#    3863 for Example: samples, features, samples_singlecell etc. \
# ...
