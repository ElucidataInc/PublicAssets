# %% [markdown]
# # Welcome to Polly Python3 Notebook.

# %%
pip install polly-python --upgrade
# Out:
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, http://54.245.179.143:80/
# ...
#      |████████████████████████████████| 130 kB 18.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 11.0 MB 30.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 135 kB 73.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 4.2 MB 67.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 79 kB 17.5 MB/s eta 0:00:01
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# awscli 1.22.74 requires botocore==1.24.19, but you have botocore 1.31.9 which is incompatible.
# awscli 1.22.74 requires s3transfer<0.6.0,>=0.5.0, but you have s3transfer 0.6.1 which is incompatible.
# ...

# %%
# sync file
# !polly files sync -s "polly://new_omix_for_refac_2 /" -d "new_omix_for_refac_2/" -y
# Out:
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# A new version of Polly CLI is available. To update, execute the command npm update -g @elucidatainc/pollycli
# Sync complete!

# %%
import os
from polly.auth import Polly
API_KEY="eWJtdThpbDE5YTo6QzFvWFhYR1QxeDZtV29tTlhYOEthNUFxdWdCN2N2ZGMzR2RhcGh2WQ=="
Polly.auth(API_KEY, env="testpolly")

# %%
from polly.omixatlas import OmixAtlas
omixatlas = OmixAtlas()

# %% [markdown]
# # Repository service functions

# %%
# test case 6
# field name upper case in datamatrix field of source = all, datatype = all

with open("/import/new_omix_for_refac_2/new_omix_for_refac.json","r") as file:
    schema_data = json.load(file)

omixatlas.validate_schema(schema_data)
# Out:
# Schema update didn’t go through because there’s a mistake in the schema. That mistake is summarised in the table below:
# ╒════╤══════════╤════════════╤═══════════════════════╤════════════════╤═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╕
# │    │ Source   │ Datatype   │ field_name            │ attribute      │ message                                                                                                                                                                                                                                                   │
# ...

# %%
# test 7 ->
# Reingestion-> changing an attribute value of a field (one of original_name , type, is_keyword, is_array)
# changing original name of `data_matrix_field`

repo_key = "1687428145396"

schema_file_path_for_insertion = "/import/new_omix_for_refac_2/new_omix_for_refac_2.json"

with open(schema_file_path_for_insertion, "r") as schema_file:
    schema_data_for_insertion = json.load(schema_file)

omixatlas.update_schema(repo_key, schema_data_for_insertion)
# Out:
# Schema has no errors
# The data needs to be re-ingested to accommodate the changes made in the schema. This may take from a few minutes to a few hours depending on the number of datasets in the atlas. The repository will be locked for this time and any further changes in the schema or properties of  omixatlas can not be done. Please refer to the ingestion monitoring dashboard to check the status of re-indexing.

# %% [markdown]
# # OmixAtlas service functions

# %%
omixatlas.get_all_omixatlas()
# Out:
# {'data': [{'repo_id': '1687428192072',
#    'repo_name': 'new_omix_for_refac_3',
#    'indexes': {},
#    'v2_indexes': {},
#    'sources': [],
#    'datatypes': [],
#    'dataset_count': 0,
#    'disease_count': 0,
#    'tissue_count': 0,
#    'organism_count': 0,
#    'cell_line_count': 0,
#    'cell_type_count': 0,
#    'drug_count': 0,
#    'data_type_count': 0,
#    'data_source_count': 0,
#    'sample_count': 0,
#    'normal_sample_count': 0},
#   {'repo_id': '1687428145396',
#    'repo_name': 'new_omix_for_refac_2',
#    'indexes': {},
#    'v2_indexes': {},
#    'sources': [],
#    'datatypes': [],
#    'dataset_count': 0,
#    'disease_count': 0,
#    'tissue_count': 0,
#    'organism_count': 0,
#    'cell_line_count': 0,
#    'cell_type_count': 0,
#    'drug_count': 0,
#    'data_type_count': 0,
#    'data_source_count': 0,
#    'sample_count': 0,
#    'normal_sample_count': 0},
#   {'repo_id': '1688711659012',
#    'repo_name': 'july_test',
#    'v2_indexes': {},
# ...

# %%
omixatlas.omixatlas_summary("geo")
# Out:
# {'data': {'repo_name': 'geo',
#   'repo_id': '1643016586529',
#   'indexes': {'files': 'geo_files',
#    'gct_col_metadata': 'geo_gct_col_metadata'},
#   'v2_indexes': {'files': 'geo_files',
#    'gct_col_metadata': 'geo_gct_col_metadata'},
#   'linked_workspace_id': '15196',
#   'sources': [{'geo': 5}, {'source': 1}, {'vfv': 1}],
#   'datatypes': [{'transcriptomics': 6}, {'': 1}],
#   'dataset_count': 7,
#   'disease_count': 12,
#   'tissue_count': 8,
#   'organism_count': 3,
#   'cell_line_count': 5,
#   'cell_type_count': 6,
#   'drug_count': 2,
#   'data_type_count': 2,
#   'data_source_count': 3,
#   'sample_count': 1741.0,
#   'normal_sample_count': 154446}}

# %% [markdown]
# # Workspaces service

# %%
from polly.workspaces import Workspaces
workspace = Workspaces()

# %%
workspace.fetch_my_workspaces()
# Out:
#     Workspace_id                        Workspace_name  status description  \
# 0          15323               schema_read_refactoring  active
# 1          15293  insert_validation_schema_refactoring  active
# 2          15277             validation_ingestion_demo  active
# 3          15265                    UX_GAPS_VALIDATION  active
# 4          15251    validation_dataset_multiple_src_dp  active
# ..           ...                                   ...     ...         ...
# 57          2596                              epi_test  active        None
# 58          2585                            quant_test  active        None
# 59          2573                              metscape  active        None
# 60          2565                  statemanagement_test  active        None
# 61          2544                                 Karma  active       Karma
#
#           last_modified tag_names  favourite  watch
# 0   2023-07-14 08:22:25        []      False  False
# ...

# %%
workspace.create_workspace("example_test","description")
# Out:
# INFO:root:Workspace Created !
# {'id': 15330,
#  'name': 'example_test',
#  'status': 1,
#  'active': 't',
#  'description': 'description',
#  'created_time': '2023-07-24 11:18:04.764928',
#  'last_modified': '2023-07-24 11:18:04.764928',
#  'creator': '191',
#  'project_property': {'type': 'workspaces', 'labels': ''},
#  'organisation': 1,
#  'tag_names': []}
