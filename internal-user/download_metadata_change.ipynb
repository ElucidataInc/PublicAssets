# %% [markdown]
# # Welcome to Polly Python3 Notebook.

# %%
pip install https://elucidatainc.github.io/PublicAssets/builds/polly-python/tests/testpolly/polly_python-0.2.8_download_metadata-py3-none-any.whl
# Out:
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, http://54.245.179.143:80/
# ...
#      |████████████████████████████████| 99 kB 4.3 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 15.3 MB 5.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 510 kB 147.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 128 kB 140.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 297 kB 142.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 149 kB 137.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 4.2 MB 135.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 42 kB 3.4 MB/s s eta 0:00:01
# ...
#      |████████████████████████████████| 52 kB 3.2 MB/s s eta 0:00:01
# ...
#      |████████████████████████████████| 7.2 MB 116.1 MB/s eta 0:00:01
# ...

# %%
from polly.auth import Polly
from polly.omixatlas import OmixAtlas
AUTH_TOKEN=(os.environ['POLLY_REFRESH_TOKEN'])
Polly.auth(AUTH_TOKEN)
omix = OmixAtlas()

# %%
omix.download_metadata("geo","GSE100000_GPL17021","/import")
# Out:
# The dataset level metadata for dataset = GSE100000_GPL17021 has been downloaded at : = /import/GSE100000_GPL17021.json

# %%
omix.download_metadata("geo","GSE100000_GPL17021","/import","original_name")
# Out:
# The dataset level metadata for dataset = GSE100000_GPL17021 has been downloaded at : = /import/GSE100000_GPL17021.json

# %%
omix.download_metadata("geo","GSE100000_GPL17021","/import","repo_name")
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterException                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 omix.download_metadata("geo","GSE100000_GPL17021","/import","repo_name")
#
# File ~/.local/lib/python3.10/site-packages/polly/omixatlas.py:3180, in OmixAtlas.download_metadata(self, repo_key, dataset_id, file_path, metadata_key)
#    3178     raise InvalidParameterException("file_path")
#    3179 if not (metadata_key.lower() in ["field_name", "original_name"]):
# -> 3180     raise InvalidParameterException("metadata_key")
#    3181 if not os.path.exists(file_path):
#    3182     raise InvalidPathException
#
# InvalidParameterException: Empty or Invalid Parameters = metadata_key.
