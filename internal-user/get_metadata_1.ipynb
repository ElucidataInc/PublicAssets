# %% [markdown]
# # Welcome to Polly Python3 Notebook.

# %%
pip install https://elucidatainc.github.io/PublicAssets/builds/polly-python/tests/testpolly/polly_python-0.2.9_get_metadata-py3-none-any.whl
# Out:
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, http://54.245.179.143:80/
# ...
#      |████████████████████████████████| 106 kB 6.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 7.2 MB 6.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 149 kB 84.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 15.2 MB 72.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 129 kB 85.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 52 kB 2.7 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 510 kB 76.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.1 MB 73.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 61 kB 16.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 4.2 MB 72.4 MB/s eta 0:00:01
# ...

# %%
from polly.auth import Polly
from polly.omixatlas import OmixAtlas
AUTH_TOKEN=(os.environ['POLLY_REFRESH_TOKEN'])
Polly.auth(AUTH_TOKEN)

# %%
omix = OmixAtlas()
df = omix.get_metadata("geo","GSE100053_GPL10558","samples")

# %%
df
# Out:
#                                title taxid_ch1  \
# 0   PLACENTA_Wk4_Tr1___108.1589.1.1.      9606
# 1   PLACENTA_Wk4_Tr1___108.1590.1.1.      9606
# 2   PLACENTA_Wk4_Tr1___108.1592.1.1.      9606
# 3    PLACENTA_Wk5_Tr1___108.1345.1.1      9606
# 4    PLACENTA_Wk5_Tr1___108.1348.1.1      9606
# ..                               ...       ...
# 60     Primary_CTB_wk18_581.1922.1.1      9606
# 61   Primary_CTB_wk18.1_581.1923.1.1      9606
# 62     Primary_CTB_wk20_581.1583.1.1      9606
# 63     Primary_CTB_wk39_581.1587.1.1      9606
# 64     Primary_CTB_wk39_581.1588.1.1      9606
#
#                                  extract_protocol_ch1 label_ch1  \
# 0   Total RNA was purified using the MirVana RNA e...    Biotin
# 1   Total RNA was purified using the MirVana RNA e...    Biotin
# 2   Total RNA was purified using the MirVana RNA e...    Biotin
# 3   Total RNA was purified using the MirVana RNA e...    Biotin
# 4   Total RNA was purified using the MirVana RNA e...    Biotin
# ...

# %%
df = omix.get_metadata(9,"GSE100680_GPL10558","samples")

# %%
df
# Out:
#                              title  \
# 0   neural progenitor C11 d45 rep1
# 1   neural progenitor C11 d45 rep3
# 2   neural progenitor C86 d45 rep1
# 3   neural progenitor C86 d45 rep2
# 4   neural progenitor C86 d45 rep3
# 5                     C11 d65 rep1
# 6                     C11 d65 rep2
# 7                     C11 d65 rep3
# 8                     C86 d65 rep1
# 9                     C86 d65 rep2
# 10                    C86 d65 rep3
# 11  neural progenitor C18 d45 rep1
# 12  neural progenitor C18 d45 rep3
# 13  neural progenitor C87 d45 rep1
# 14  neural progenitor C87 d45 rep2
# 15  neural progenitor C87 d45 rep3
# 16                    C18 d65 rep1
# 17                    C18 d65 rep2
# 18                    C18 d65 rep3
# 19                    C87 d65 rep1
# 20                    C87 d65 rep2
# 21                    C87 d65 rep3
# 22   neural progenitor A3 d45 rep1
# 23   neural progenitor A3 d45 rep2
# 24   neural progenitor A3 d45 rep3
# ...

# %%
df = omix.get_metadata("geo","GSE100000_GPL17021","dataset")
# table_name entered is incorrect, only "samples" accepted
# Out:
# ---------------------------------------------------------------------------
# paramException                            Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 df = omix.get_metadata("geo","GSE100000_GPL17021","dataset")
#       2 # table_name entered is incorrect, only "samples" accepted
#
# File ~/.local/lib/python3.10/site-packages/polly/omixatlas.py:3623, in OmixAtlas.get_metadata(self, repo_key, dataset_id, table_name)
#    3618             raise paramException(
#    3619                 title="Param Error",
#    3620                 detail="Argument 'table_name' is either empty or invalid. Please try again.",
#    3621             )
#    3622         if table_name.lower() != "samples":
# -> 3623             raise paramException(
#    3624                 title="Param Error",
#    3625                 detail="Argument 'table_name' not valid, please query 'SHOW TABLES IN repo_name' \
# ...

# %%
df = omix.get_metadata("geo","GSE100000_GPL1702","samples")
# incorrect dataset_id
# Out:
# ---------------------------------------------------------------------------
# RequestException                          Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 df = omix.get_metadata("geo","GSE100000_GPL1702","samples")
#       2 # incorrect dataset_id
#
# File ~/.local/lib/python3.10/site-packages/polly/omixatlas.py:3634, in OmixAtlas.get_metadata(self, repo_key, dataset_id, table_name)
#    3632     repo_key = str(repo_key)
#    3633 # validate repo_key and dataset_id using download_data() function
# -> 3634 download_dict = self.download_data(repo_key, dataset_id)
#    3635 if download_dict:
#    3636     # the pair repo_key and dataset_id is valid, do nothing
#    3637     pass
#
# File ~/.local/lib/python3.10/site-packages/polly/tracking.py:48, in Track.track_decorator.<locals>.wrapper_function(*args, **kwargs)
#      46         return result
#      47 else:
# ---> 48     raise returned_err
#
# ...
