# %%
pip install https://elucidatainc.github.io/PublicAssets/builds/polly-python/tests/testpolly/polly_python-2.5.0-py3-none-any.whl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.3/168.3 kB 3.3 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 75.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 21.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tabulate
#     Found existing installation: tabulate 0.8.10
#     Uninstalling tabulate-0.8.10:
#       Successfully uninstalled tabulate-0.8.10
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.2.0
#     Uninstalling charset-normalizer-3.2.0:
#       Successfully uninstalled charset-normalizer-3.2.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
# ...

# %%
from polly.auth import Polly
from polly.workspaces import Workspaces
API_KEY = ""
Polly.auth(API_KEY, env="testpolly")
w = Workspaces()
workspace_obj = Workspaces()

# %%
w.create_workspace("test_function_anshu")
# Out:
# INFO:root:Workspace Created !
# {'name': 'test_function_anshu',
#  'description': None,
#  'project_property': {'type': 'workspaces', 'labels': ''},
#  'created_time': '2024-09-18 11:38:28',
#  'last_modified': '2024-09-18 11:38:28',
#  'status': 1,
#  'creator': 1698038337,
#  'organisation': 1,
#  'id': 16562,
#  'tag_names': []}

# %%
w._fetch_workspaces_iteratively()
# Out:
# [{'id': 16562,
#   'name': 'test_function_anshu',
#   'status': 'active',
#   'description': None,
#   'last_modified': '2024-09-18 11:38:28',
#   'tag_names': [],
#   'favourite': False,
#   'watch': False},
#  {'id': 16556,
#   'name': 'new WS 21',
#   'status': 'active',
#   'description': '',
#   'last_modified': '2024-09-12 09:54:16',
#   'tag_names': [],
#   'favourite': False,
#   'watch': False},
#  {'id': 16552,
#   'name': 'tryyy',
#   'status': 'active',
#   'description': '',
#   'last_modified': '2024-09-03 10:29:36',
#   'tag_names': [],
#   'favourite': False,
#   'watch': False},
#  {'id': 15495,
#   'name': 'test_2024_21Aug',
#   'status': 'active',
#   'description': None,
#   'last_modified': '2024-08-30 10:55:18',
#   'tag_names': [],
#   'favourite': False,
#   'watch': False},
#  {'id': 15492,
#   'name': 'new_workspace_testing_4__Restored',
#   'status': 'active',
#   'description': None,
#   'last_modified': '2024-09-18 11:38:03',
#   'tag_names': [],
# ...

# %%
w.fetch_my_workspaces()
# Out:
#     Workspace_id                                     Workspace_name  status  \
# 0          16562                                test_function_anshu  active
# 1          15492                  new_workspace_testing_4__Restored  active
# 2          16556                                          new WS 21  active
# 3          16552                                              tryyy  active
# 4          15322  Common NBs added text for checking name with l...  active
# 5          15495                                    test_2024_21Aug  active
# 6          16531                                  _PRD-870_Restored  active
# 7          16528                                   PRD-741_Restored  active
# 8          15424                                 Curation-Notebooks  active
# 9          16522                        test new workspace_Restored  active
# 10         15443                          Pipelines module polly py  active
# ...

# %%
w.create_copy(15492,"Polly Notebook Fri Aug 23 2024 13:42:59.ipynb",16562)
# Out:
# Workspace_copy started, You will be notified upon completion.
# Copy Operation Successful!

# %%
workspace_obj.upload_to_workspaces(16562, "Screenshot 2024-08-20 at 6.04.02 PM.png","new_test")
# Out:
# INFO:root:Upload successful on workspace-id=16562.

# %%
workspace_obj.download_from_workspaces(16562, "Polly Notebook Fri Aug 23 2024 13:42:59.ipynb", "new_test")
# Out:
# INFO:root:Download successful to path=new_test

# %%
workspace_obj.download_from_workspaces(16562, "test_copy","new_test", copy_workspace_path = False)
# Out:
# INFO:root:Download successful to path=new_test

# %%
workspace_obj.sync_data(16562, "polly://test_copy","new_test")
# Out:
# INFO:root:Sync successful on workspace-id=16562.

# %%
workspace_obj.sync_data(16562, "new_test","polly:///")
# Out:
# INFO:root:Sync successful on workspace-id=16562.
