# %% [markdown]
# # Welcome to Polly Python3 Notebook.

# %%
pip install https://elucidatainc.github.io/PublicAssets/builds/polly-python/tests/testpolly/polly_python-0.3.0_get_metadata-py3-none-any.whl
# Out:
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, http://54.245.179.143:80/
# ...
#      |████████████████████████████████| 114 kB 6.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 134 kB 12.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 15.3 MB 68.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.1 MB 80.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 142 kB 79.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 50 kB 15.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 225 kB 79.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.7 MB 70.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 320 kB 78.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 297 kB 81.3 MB/s eta 0:00:01
# ...

# %%
AUTH_TOKEN=(os.environ['POLLY_REFRESH_TOKEN'])
import os
from polly.auth import Polly
from polly.omixatlas import OmixAtlas
Polly.auth(AUTH_TOKEN)

# %%
omixatlas = OmixAtlas()
omixatlas.session.env
# Out:
# 'polly'

# %%
# valid case
repo_key = "geo"
dataset_id = "GSE100000_GPL17021"
table_name = "samples"
omixatlas.get_metadata(repo_key, dataset_id, table_name)
# Out:
#                                          title taxid_ch1  \
# 0                                 BirA_control     10090
# 1          Fosl1-FB_cloneB11 (high expression)     10090
# 2            Fosl1-FB_cloneC2 (low expression)     10090
# 3                         RNA-seq:BirA_control     10090
# 4  RNA-seq:FB-Fosl1_cloneB11 (high expression)     10090
# 5    RNA-seq:FB-Fosl1_cloneC2 (low expression)     10090
#
#                                  growth_protocol_ch1  \
# 0  Mouse J1 ES cells were maintained in Dulbecco’...
# 1  Mouse J1 ES cells were maintained in Dulbecco’...
# 2  Mouse J1 ES cells were maintained in Dulbecco’...
# 3  Mouse J1 ES cells were maintained in Dulbecco’...
# 4  Mouse J1 ES cells were maintained in Dulbecco’...
# 5  Mouse J1 ES cells were maintained in Dulbecco’...
#
#                                 extract_protocol_ch1  \
# 0  Cells were cross-linked in 1% formaldehyde for...
# 1  Cells were cross-linked in 1% formaldehyde for...
# ...

# %%
# invalid case, dataset of geo but repo_key is tcga
repo_key = "tcga"
dataset_id = "GSE100000_GPL17021"
table_name = "samples"
omixatlas.get_metadata(repo_key, dataset_id, table_name)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Input In [4], in <cell line: 5>()
#       3 dataset_id = "GSE100000_GPL17021"
#       4 table_name = "samples"
# ----> 5 omixatlas.get_metadata(repo_key, dataset_id, table_name)
#
# File ~/.local/lib/python3.10/site-packages/polly/tracking.py:48, in Track.track_decorator.<locals>.wrapper_function(*args, **kwargs)
#      46         return result
#      47 else:
# ---> 48     raise returned_err
#
# File ~/.local/lib/python3.10/site-packages/polly/tracking.py:20, in Track.track_decorator.<locals>.wrapper_function(*args, **kwargs)
#      18 execution_flag = False
#      19 try:
# ---> 20     result = function(*args, **kwargs)
#      21     execution_flag = True
#      22 except Exception as e:
#
# File ~/.local/lib/python3.10/site-packages/polly/omixatlas.py:4018, in OmixAtlas.get_metadata(self, repo_key, dataset_id, table_name)
# ...

# %%
# invalid case, invalid dataset_id 
repo_key = "geo"
dataset_id = "GSE100000_GPL170"
table_name = "samples"
omixatlas.get_metadata(repo_key, dataset_id, table_name)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Input In [5], in <cell line: 5>()
#       3 dataset_id = "GSE100000_GPL170"
#       4 table_name = "samples"
# ----> 5 omixatlas.get_metadata(repo_key, dataset_id, table_name)
#
# File ~/.local/lib/python3.10/site-packages/polly/tracking.py:48, in Track.track_decorator.<locals>.wrapper_function(*args, **kwargs)
#      46         return result
#      47 else:
# ---> 48     raise returned_err
#
# File ~/.local/lib/python3.10/site-packages/polly/tracking.py:20, in Track.track_decorator.<locals>.wrapper_function(*args, **kwargs)
#      18 execution_flag = False
#      19 try:
# ---> 20     result = function(*args, **kwargs)
#      21     execution_flag = True
#      22 except Exception as e:
#
# File ~/.local/lib/python3.10/site-packages/polly/omixatlas.py:4018, in OmixAtlas.get_metadata(self, repo_key, dataset_id, table_name)
# ...
