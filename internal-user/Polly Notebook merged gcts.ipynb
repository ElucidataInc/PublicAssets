# %% [markdown]
# # Welcome to Polly Python3 Notebook.

# %%
pip install https://elucidatainc.github.io/PublicAssets/builds/polly-python/tests/testpolly/polly_python-0.2.3-py3-none-any.whl
# Out:
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, http://54.245.179.143:80/
# ...
#      |████████████████████████████████| 72 kB 1.0 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 510 kB 7.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.5 MB 75.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 42 kB 3.4 MB/s s eta 0:00:01
# ...
#      |████████████████████████████████| 134 kB 147.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 61 kB 24.3 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 128 kB 145.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 297 kB 139.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 50 kB 16.6 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 12.0 MB 17.7 MB/s eta 0:00:01
# ...

# %%
from polly.auth import Polly
from polly.cohort import Cohort
AUTH_TOKEN=(os.environ['POLLY_REFRESH_TOKEN'])
Polly.auth(AUTH_TOKEN)

# %%
c = Cohort()
c.create_cohort("/import","tcga_cohort","description","tcga",["ACC_Mutation_TCGA-OR-A5J2-01A-11D-A29I-10","ACC_Mutation_TCGA-OR-A5JL-01A-11D-A29I-10","BLCA_Mutation_TCGA-4Z-AA82-01A-11D-A391-08"])
# Out:
# INFO:root:Cohort Created !
# Initializing process...
# ...
# Adding metadata to cohort: 100%|██████████| 3/3 [00:02<00:00,  1.17it/s]
# INFO:root:'3' dataset/s added to Cohort!

# %%
c.create_merged_gct("/import")
# Out:
# INFO:cmap_logger:parsing gct file
# INFO:cmap_logger:Reading GCT: /import/tcga_cohort.pco/tcga_ACC_Mutation_TCGA-OR-A5JL-01A-11D-A29I-10.gct
# INFO:cmap_logger:parsing gct file
# INFO:cmap_logger:Reading GCT: /import/tcga_cohort.pco/tcga_ACC_Mutation_TCGA-OR-A5J2-01A-11D-A29I-10.gct
# INFO:cmap_logger:parsing gct file
# INFO:cmap_logger:Reading GCT: /import/tcga_cohort.pco/tcga_BLCA_Mutation_TCGA-4Z-AA82-01A-11D-A391-08.gct
# INFO:cmap_logger:GCT has been written to /import/tcga_cohort.gct
