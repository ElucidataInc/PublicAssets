# %%
pip install https://elucidatainc.github.io/PublicAssets/builds/polly-python/tests/testpolly/polly_python-1.5.0-py3-none-any.whl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.7/162.7 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 1.1 MB/s eta 0:00:00a 0:00:01
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: polly-python
#     Found existing installation: polly-python 1.0.0
#     Uninstalling polly-python-1.0.0:
#       Successfully uninstalled polly-python-1.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyterlab-server 2.24.0 requires requests>=2.28, but you have requests 2.25.1 which is incompatible.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from polly.auth import Polly
from polly.workspaces import Workspaces
API_KEY = "OTdlOTM4YmVmYzo6MDZjODk3ZjQwMzZkYTg0ZmJkZjQ2N2E2ZTQyODIzOGY5ZjRhYWYyNQ=="
Polly.auth(API_KEY, env="testpolly")
w = Workspaces()

# %%
w.create_workspace("new_workspace_2")
# Out:
# INFO:root:Workspace Created !
# {'name': 'new_workspace_2',
#  'description': None,
#  'project_property': {'type': 'workspaces', 'labels': ''},
#  'created_time': '2024-05-22 14:47:18',
#  'last_modified': '2024-05-22 14:47:18',
#  'status': 1,
#  'creator': 1709822253,
#  'organisation': 1,
#  'id': 16526,
#  'tag_names': []}

# %%
w._fetch_workspaces_iteratively()
# Out:
# [{'id': 16526,
#   'name': 'new_workspace_2',
#   'description': None,
#   'status': 'active',
#   'watch': False,
#   'favourite': False,
#   'last_modified': '2024-05-22 14:47:18',
#   'tag_names': []},
#  {'description': None,
#   'name': 'new_test_workspace2',
#   'id': 16524,
#   'status': 'active',
#   'watch': False,
#   'favourite': False,
#   'last_modified': '2024-05-21 06:58:23',
#   'tag_names': []},
#  {'description': None,
#   'name': 'new_test_workspace',
#   'id': 16523,
#   'status': 'archived',
#   'watch': False,
#   'favourite': False,
#   'last_modified': '2024-05-15 13:24:26',
#   'tag_names': []},
#  {'id': 16521,
#   'name': 'workspace_test',
#   'description': None,
#   'status': 'active',
#   'watch': False,
#   'favourite': False,
#   'last_modified': '2024-05-14 12:18:57',
#   'tag_names': []},
#  {'id': 16520,
#   'name': 'workspace_test',
#   'description': None,
#   'status': 'active',
#   'watch': False,
#   'favourite': False,
# ...

# %%
w.fetch_my_workspaces()
# Out:
#    Workspace_id         Workspace_name description    status  watch  \
# 0         16526        new_workspace_2        None    active  False
# 1         16503           my_workspace                active  False
# 2         16518          New_Workspace        None    active  False
# 3         16524    new_test_workspace2        None    active  False
# 4         16523     new_test_workspace        None  archived  False
# 5         16521         workspace_test        None    active  False
# 6         16520         workspace_test        None    active  False
# 7         16519  test_create_workspace        None    active  False
#
#    favourite        last_modified tag_names
# 0      False  2024-05-22 14:47:18        []
# 1      False  2024-05-22 14:46:03        []
# 2      False  2024-05-22 12:25:08        []
# 3      False  2024-05-21 06:58:23        []
# 4      False  2024-05-15 13:24:26        []
# 5      False  2024-05-14 12:18:57        []
# ...

# %%
w.list_contents("16503")
# Out:
#                                         file_name       size  \
# 0                                        plan.txt  285.46 KB
# 1   Polly Notebook Thu Apr 04 2024 20:11:56.ipynb    1.27 KB
# 2   Polly Notebook Fri Apr 12 2024 18:14:20.ipynb      577 B
# 3   Polly Notebook Mon Apr 15 2024 15:29:21.ipynb       65 B
# 4   Polly Notebook Fri Apr 19 2024 09:59:07.ipynb   43.53 KB
# 5                                      new_folder          -
# 6   Polly Notebook Thu Apr 04 2024 20:10:38.ipynb       65 B
# 7   Polly Notebook Mon Apr 15 2024 15:29:51.ipynb   29.26 KB
# 8   Polly Notebook Fri Apr 12 2024 14:16:40.ipynb   61.64 KB
# 9   Polly Notebook Wed May 22 2024 19:50:07.ipynb       65 B
# 10  Polly Notebook Mon Apr 15 2024 11:11:13.ipynb       65 B
# 11  Polly Notebook Fri Apr 12 2024 18:12:21.ipynb       65 B
# 12  Polly Notebook Mon Apr 15 2024 11:11:37.ipynb   37.06 KB
# 13  Polly Notebook Thu Apr 18 2024 22:05:39.ipynb      577 B
# ...

# %%
w.create_copy(16503,"new_folder/",16518)
# Out:
# Workspace_copy started, You will be notified upon completion.
# Copy Operation Successful!
