# %% [markdown]
# # Welcome to Polly Python3 Notebook.

# %%
pip install https://elucidatainc.github.io/PublicAssets/builds/polly-python/tests/devpolly/polly_python-3.1.0-py3-none-any.whl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 152 kB 3.7 MB/s eta 0:00:01
# ...
#   Attempting uninstall: polly-python
#     Found existing installation: polly-python 3.0.0
#     Uninstalling polly-python-3.0.0:
#       Successfully uninstalled polly-python-3.0.0
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install polly-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from polly.pipelines import Pipelines

# %%
pipeline = Pipelines(env="devpolly", token="YzZmMDdjYTkyMDo6ZDQwNDQyNmM1MmQ5YzZhNTA2ZGZiYmMzMmQxYWY0YTZiODg4NDZjZQ==")

# %%
# Get all pipelines
pipelines = pipeline.list_pipelines()
pipelines
# Out:
# [{'id': '6ac2490c-353c-4875-8ac2-e04b3b83083b',
#   'type': 'pipelines',
#   'attributes': {'name': 'nfcore_wes_sarek',
#    'display_name': 'nfcore_wes_sarek',
#    'description': None,
#    'executor': 'nextflow',
#    'deployment_stage': 'dev',
#    'config': {'infra': {'storage': 120,
#      'provider': 'pnap',
#      'supported_providers': ['aws', 'pnap']},
#     'executor': {'config_file': 'src/nextflow.config',
#      'params_file': 'src/params.json'}},
#    'org_id': '1',
#    'user_id': '1703140688',
#    'user_name': 'polly@elucidata.io',
#    'created_at': 1737022692893,
#    'last_updated_at': 1738583823465}},
#  {'id': 'b90c2394-5614-46bc-a7eb-aa79428bc2ce',
#   'type': 'pipelines',
#   'attributes': {'name': 'acep_etl_v1',
#    'display_name': 'acep_etl_v1',
#    'description': None,
#    'executor': 'nextflow',
#    'deployment_stage': 'dev',
#    'config': {'infra': {'storage': 120},
#     'executor': {'config_file': 'src/nextflow.config',
# ...

# %%
# Create Batch with options
batch = pipeline.create_batch(
    pipeline_id="8c2327b3-f91a-4411-8558-a5ef71b78539",
    name="test delete storage api",
    priority="high",
    tags={},
    domain_context={}
)
print(batch)
# Out:
# {'id': '838f5ad7-e339-426d-8b3c-8d466d483665', 'type': 'batches', 'attributes': {'name': 'test delete storage api', 'description': '', 'created_at': 1739371168501, 'pipeline_id': '8c2327b3-f91a-4411-8558-a5ef71b78539', 'priority': 'high', 'domain_context': {}, 'tags': {'org_id': '1'}, 'org_id': '1', 'user_id': '1737543167', 'user_name': 'Snehalakshmi S', 'num_runs': 0, 'num_successful_runs': 0, 'num_failed_runs': 0, 'status': 'PENDING', 'last_updated_at': 1739371168501}}

# %%
run = pipeline.submit_run(
    batch_id = "838f5ad7-e339-426d-8b3c-8d466d483665",
    parameters = {
       "dataset_id":"GSE175766_GPL19057_raw",
       "check_data_type":"No",
       "config_file":"nextflow.config",
       "params_file":"params.json",
       "minion_reqd":"no",
       "rseqc_reqd":"no",
       "make_gct_custom":"no",
       "output_to_OA":"no",
       "repo_id":"1677126277716",
       "gsm_list_path":"mappings/GSE175766_GPL19057_manual/gsms.txt",
       "token":"YzZmMDdjYTkyMDo6ZDQwNDQyNmM1MmQ5YzZhNTA2ZGZiYmMzMmQxYWY0YTZiODg4NDZjZQ=="
    },
    config = {
        "infra": {
            #"provider": "aws"
            "provider": "pnap"
            #"pnap_region": "ash"
        }
    }
)

# %%
print(run)
# Out:
# {'id': '9a832ecb-0a81-4eca-8a51-ff86f6e4dcf6', 'type': 'runs', 'attributes': {'name': 'Run created on February-12-2025 at 20:12', 'parameters': {'dataset_id': 'GSE175766_GPL19057_raw', 'check_data_type': 'No', 'config_file': 'nextflow.config', 'params_file': 'params.json', 'minion_reqd': 'no', 'rseqc_reqd': 'no', 'make_gct_custom': 'no', 'output_to_OA': 'no', 'repo_id': '1677126277716', 'gsm_list_path': 'mappings/GSE175766_GPL19057_manual/gsms.txt', 'token': 'YzZmMDdjYTkyMDo6ZDQwNDQyNmM1MmQ5YzZhNTA2ZGZiYmMzMmQxYWY0YTZiODg4NDZjZQ=='}, 'config': {'infra': {'storage': 120, 'provider': 'pnap'}, 'executor': {'config_file': 'src/nextflow.config', 'params_file': 'src/params.json'}}, 'batch_id': '838f5ad7-e339-426d-8b3c-8d466d483665', 'stage': 'Pre-processing', 'progress': '1/1', 'pending': False, 'errored': False, 'finished': False, 'cancelled': False, 'status': 'RUNNING', 'created_at': 1739371341948, 'last_updated_at': 1739371341948}}

# %%
res = pipeline.delete_storage("9a832ecb-0a81-4eca-8a51-ff86f6e4dcf6")
print(res)
# Out:
# {'message': 'storage deleted successfully'}
