# %%
pip install https://elucidatainc.github.io/PublicAssets/builds/polly-python/tests/testpolly/polly_python-2.5.0-py3-none-any.whl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.3/168.3 kB 4.3 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 31.3 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 10.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tabulate
#     Found existing installation: tabulate 0.8.10
#     Uninstalling tabulate-0.8.10:
#       Successfully uninstalled tabulate-0.8.10
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.2.0
#     Uninstalling charset-normalizer-3.2.0:
#       Successfully uninstalled charset-normalizer-3.2.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
# ...

# %%
from polly.auth import Polly
from polly.workspaces import Workspaces
API_KEY = ""
Polly.auth(API_KEY, env="testpolly")
w = Workspaces()

# %%
w.create_workspace("new_workspace_6")
# Out:
# INFO:root:Workspace Created !
# {'name': 'new_workspace_6',
#  'description': None,
#  'project_property': {'type': 'workspaces', 'labels': ''},
#  'created_time': '2024-09-16 13:42:42',
#  'last_modified': '2024-09-16 13:42:42',
#  'status': 1,
#  'creator': 1709822253,
#  'organisation': 1,
#  'id': 16560,
#  'tag_names': []}

# %%
w._fetch_workspaces_iteratively()
# Out:
# [{'id': 16560,
#   'name': 'new_workspace_6',
#   'status': 'active',
#   'description': None,
#   'last_modified': '2024-09-16 13:42:42',
#   'tag_names': [],
#   'favourite': False,
#   'watch': False},
#  {'id': 16559,
#   'name': 'new_workspace_6',
#   'status': 'active',
#   'description': None,
#   'last_modified': '2024-09-16 12:28:44',
#   'tag_names': [],
#   'favourite': False,
#   'watch': False},
#  {'id': 16557,
#   'name': 'new_test',
#   'status': 'active',
#   'description': 'for permissions issue abcd',
#   'last_modified': '2024-09-12 15:06:04',
#   'tag_names': [],
#   'favourite': False,
#   'watch': False},
#  {'id': 16535,
#   'name': 'new_workspace_5',
#   'status': 'active',
#   'description': None,
#   'last_modified': '2024-06-28 14:47:10',
#   'tag_names': [],
#   'favourite': False,
#   'watch': False},
#  {'id': 16533,
#   'name': 'new_test_workspace4',
#   'status': 'active',
#   'description': None,
#   'last_modified': '2024-06-24 11:51:58',
# ...

# %%
w.fetch_my_workspaces()
# Out:
#     Workspace_id         Workspace_name    status                 description  \
# 0          16560        new_workspace_6    active                        None
# 1          16559        new_workspace_6    active                        None
# 2          16518          New_Workspace    active                        None
# 3          16503           my_workspace    active
# 4          16557               new_test    active  for permissions issue abcd
# 5          14643         LIB-215_report    active
# 6          16535        new_workspace_5    active                        None
# 7          16533    new_test_workspace4    active                        None
# 8          16532    new_test_workspace4    active                        None
# 9          16526        new_workspace_2    active                        None
# 10         16521         workspace_test    active                        None
# 11         16524    new_test_workspace2    active                        None
# ...

# %%
w.list_contents("16503")
# Out:
#                                         file_name       size  \
# 0                                      new_folder          -
# 1   Polly Notebook Thu Apr 04 2024 20:10:38.ipynb     65.0 B
# 2   Polly Notebook Mon Apr 15 2024 15:29:51.ipynb   29.26 KB
# 3   Polly Notebook Fri Apr 12 2024 14:16:40.ipynb   61.64 KB
# 4   Polly Notebook Wed May 22 2024 19:50:07.ipynb     65.0 B
# 5   Polly Notebook Wed May 29 2024 16:54:35.ipynb     65.0 B
# 6   Polly Notebook Wed May 29 2024 17:19:29.ipynb    26.7 KB
# 7                                        plan.txt  285.46 KB
# 8   Polly Notebook Thu Apr 04 2024 20:11:56.ipynb    1.27 KB
# 9   Polly Notebook Fri Apr 12 2024 18:14:20.ipynb    577.0 B
# 10  Polly Notebook Mon Apr 15 2024 15:29:21.ipynb     65.0 B
# 11  Polly Notebook Fri Apr 19 2024 09:59:07.ipynb   43.53 KB
# 12  Polly Notebook Fri Jun 07 2024 15:37:28.ipynb     65.0 B
# 13  Polly Notebook Wed Aug 21 2024 16:40:30.ipynb   43.53 KB
# ...

# %%
w.create_copy(16503,"new_folder/",16559)
# Out:
# Workspace_copy started, You will be notified upon completion.
# Copy Operation Successful!

# %%
w.list_contents("16559")
# Out:
#     file_name size last_modified
# 0  new_folder    -             -
