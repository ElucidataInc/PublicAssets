# %% [markdown]
# # Welcome to Polly Python3 Notebook.

# %%
pip install https://elucidatainc.github.io/PublicAssets/builds/polly-python/tests/testpolly/polly_python-0.3.1_fetch_quilt_metadata-py3-none-any.whl
# Out:
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, http://54.245.179.143:80/
# Collecting polly-python==0.3.1-fetch-quilt-metadata
#   Downloading https://elucidatainc.github.io/PublicAssets/builds/polly-python/tests/testpolly/polly_python-0.3.1_fetch_quilt_metadata-py3-none-any.whl (119 kB)
#      |████████████████████████████████| 119 kB 6.8 MB/s eta 0:00:01
# Collecting polly-validator==0.0.1
#   Downloading polly_validator-0.0.1-py3-none-any.whl (29 kB)
# Collecting pytest>=3.0.0
#   Downloading pytest-7.3.1-py3-none-any.whl (320 kB)
#      |████████████████████████████████| 320 kB 10.5 MB/s eta 0:00:01
# Collecting datapane>=0.9.1
#   Downloading datapane-0.16.4-py3-none-any.whl (226 kB)
#      |████████████████████████████████| 226 kB 66.5 MB/s eta 0:00:01
# Collecting python-jose>=3.3.0
#   Downloading python_jose-3.3.0-py2.py3-none-any.whl (33 kB)
# Collecting retrying>=1.3.3
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Collecting elucidatacloudpathlib==0.6.6
#   Downloading elucidatacloudpathlib-0.6.6-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 12.9 MB/s eta 0:00:01
# Collecting rst2txt>=1.1.0
#   Downloading rst2txt-1.1.0-py2.py3-none-any.whl (12 kB)
# Collecting Deprecated>=1.2.6
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/site-packages (from polly-python==0.3.1-fetch-quilt-metadata) (1.4.1)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
#      |████████████████████████████████| 142 kB 76.1 MB/s eta 0:00:01
# Collecting pydantic>=0.32.0
#   Downloading pydantic-1.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 76.3 MB/s eta 0:00:01
# Requirement already satisfied: boto3>=1.17.73 in /usr/local/lib/python3.10/site-packages (from polly-python==0.3.1-fetch-quilt-metadata) (1.21.19)
# Collecting plotly>=2.0.0
#   Downloading plotly-5.14.1-py2.py3-none-any.whl (15.3 MB)
#      |████████████████████████████████| 15.3 MB 72.2 MB/s eta 0:00:01
# Collecting mixpanel>=4.10.0
#   Downloading mixpanel-4.10.0-py2.py3-none-any.whl (8.9 kB)
# Requirement already satisfied: botocore>=1.20.73 in /usr/local/lib/python3.10/site-packages (from polly-python==0.3.1-fetch-quilt-metadata) (1.24.19)
# Requirement already satisfied: requests>=2.25.1 in /usr/local/lib/python3.10/site-packages (from polly-python==0.3.1-fetch-quilt-metadata) (2.27.1)
# Collecting elucidatacmapPy==3.3.4
#   Downloading elucidatacmapPy-3.3.4-py3-none-any.whl (134 kB)
#      |████████████████████████████████| 134 kB 77.2 MB/s eta 0:00:01
# Collecting cryptography>=38.0.1
#   Downloading cryptography-40.0.2-cp36-abi3-manylinux_2_28_x86_64.whl (3.7 MB)
#      |████████████████████████████████| 3.7 MB 76.8 MB/s eta 0:00:01
# Requirement already satisfied: tqdm>=4.19.5 in /usr/local/lib/python3.10/site-packages (from polly-python==0.3.1-fetch-quilt-metadata) (4.65.0)
# Collecting joblib>=0.11
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      |████████████████████████████████| 297 kB 72.3 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.11.2 in /usr/local/lib/python3.10/site-packages (from elucidatacmapPy==3.3.4->polly-python==0.3.1-fetch-quilt-metadata) (1.22.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/site-packages (from elucidatacmapPy==3.3.4->polly-python==0.3.1-fetch-quilt-metadata) (1.16.0)
# Collecting h5py>=2.6.0
#   Downloading h5py-3.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      |████████████████████████████████| 4.6 MB 71.6 MB/s eta 0:00:01
# Collecting appdirs==1.4.4
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting rapidfuzz==2.1.1
#   Downloading rapidfuzz-2.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 61.8 MB/s eta 0:00:01
# Collecting pronto
#   Downloading pronto-2.5.4-py2.py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 16.3 MB/s eta 0:00:01
# Collecting tabulate==0.8.10
#   Downloading tabulate-0.8.10-py3-none-any.whl (29 kB)
# Collecting requests>=2.25.1
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 17.1 MB/s eta 0:00:01
# Collecting jarowinkler<1.1.0,>=1.0.3
#   Downloading jarowinkler-1.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (103 kB)
#      |████████████████████████████████| 103 kB 70.3 MB/s eta 0:00:01
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/site-packages (from requests>=2.25.1->polly-python==0.3.1-fetch-quilt-metadata) (1.26.6)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.10/site-packages (from requests>=2.25.1->polly-python==0.3.1-fetch-quilt-metadata) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/site-packages (from requests>=2.25.1->polly-python==0.3.1-fetch-quilt-metadata) (2021.5.30)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.10/site-packages (from requests>=2.25.1->polly-python==0.3.1-fetch-quilt-metadata) (4.0.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.10/site-packages (from boto3>=1.17.73->polly-python==0.3.1-fetch-quilt-metadata) (0.10.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /usr/local/lib/python3.10/site-packages (from boto3>=1.17.73->polly-python==0.3.1-fetch-quilt-metadata) (0.5.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/site-packages (from botocore>=1.20.73->polly-python==0.3.1-fetch-quilt-metadata) (2.8.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/site-packages (from cryptography>=38.0.1->polly-python==0.3.1-fetch-quilt-metadata) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=38.0.1->polly-python==0.3.1-fetch-quilt-metadata) (2.21)
# Requirement already satisfied: PyYAML<7.0.0,>=5.4.0 in /usr/local/lib/python3.10/site-packages (from datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (5.4.1)
# Collecting boltons<22.0.0,>=20.0.0
#   Downloading boltons-21.0.0-py2.py3-none-any.whl (193 kB)
#      |████████████████████████████████| 193 kB 75.9 MB/s eta 0:00:01
# Collecting click<9.0.0,>=7.1.0
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 11.2 MB/s eta 0:00:01
# Collecting cheroot<10.0.0,>=9.0.0
#   Downloading cheroot-9.0.0-py2.py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 16.1 MB/s ta 0:00:01
# Collecting dacite<2.0.0,>=1.0.2
#   Downloading dacite-1.8.0-py3-none-any.whl (14 kB)
# Collecting altair<5.0.0,>=4.0.0
#   Downloading altair-4.2.2-py3-none-any.whl (813 kB)
#      |████████████████████████████████| 813 kB 71.7 MB/s eta 0:00:01
# Requirement already satisfied: jsonschema<5.0.0,>=3.2.0 in /usr/local/lib/python3.10/site-packages (from datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (4.2.1)
# Collecting furl<3.0.0,>=2.0.0
#   Downloading furl-2.1.3-py2.py3-none-any.whl (20 kB)
# Collecting dominate<3.0.0,>=2.4.0
#   Downloading dominate-2.7.0-py2.py3-none-any.whl (29 kB)
# Collecting pyngrok<6.0.0,>=5.2.1
#   Downloading pyngrok-5.2.3.tar.gz (681 kB)
#      |████████████████████████████████| 681 kB 73.8 MB/s eta 0:00:01
# Collecting ipynbname<2022.0.0,>=2021.3.2
#   Downloading ipynbname-2021.3.2-py3-none-any.whl (4.0 kB)
# Collecting importlib_resources<6.0.0,>=3.0.0
#   Downloading importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# Requirement already satisfied: nbconvert>=5.6.1 in /usr/local/lib/python3.10/site-packages (from datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (6.3.0)
# Collecting vega-datasets<1.0.0,>=0.9.0
#   Downloading vega_datasets-0.9.0-py3-none-any.whl (210 kB)
#      |████████████████████████████████| 210 kB 79.2 MB/s eta 0:00:01
# Collecting pyarrow<11.0.0,>=6.0.0
#   Downloading pyarrow-10.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.9 MB)
#      |████████████████████████████████| 35.9 MB 78.6 MB/s eta 0:00:01
# Collecting requests-toolbelt<0.11.0,>=0.9.1
#   Downloading requests_toolbelt-0.10.1-py2.py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 7.1 MB/s  eta 0:00:01
# Collecting micawber>=0.5.0
#   Downloading micawber-0.5.4.tar.gz (18 kB)
# Collecting typing-extensions<5.0.0,>=4.4.0
#   Downloading typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Collecting click-spinner<0.2.0,>=0.1.8
#   Downloading click_spinner-0.1.10-py2.py3-none-any.whl (4.0 kB)
# Collecting posthog<3.0.0,>=1.4.0
#   Downloading posthog-2.5.0-py2.py3-none-any.whl (36 kB)
# Collecting dulwich<0.22.0,>=0.20.0
#   Downloading dulwich-0.21.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (506 kB)
#      |████████████████████████████████| 506 kB 76.1 MB/s eta 0:00:01
# Collecting datacommons<2.0.0,>=1.4.3
#   Downloading datacommons-1.4.3-py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 9.7 MB/s  eta 0:00:01
# Collecting multimethod<2.0,>=1.9
#   Downloading multimethod-1.9.1-py3-none-any.whl (10 kB)
# Collecting lxml<5.0.0,>=4.0.0
#   Downloading lxml-4.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (7.1 MB)
#      |████████████████████████████████| 7.1 MB 45.7 MB/s eta 0:00:01
# Collecting glom<24.0.0,>=22.1.0
#   Downloading glom-23.3.0-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 22.5 MB/s ta 0:00:01
# Requirement already satisfied: packaging<24.0.0,>=21.0.0 in /usr/local/lib/python3.10/site-packages (from datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (23.0)
# Collecting colorlog<7.0.0,>=4.1.0
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Collecting datacommons-pandas<0.0.4,>=0.0.3
#   Downloading datacommons_pandas-0.0.3-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 6.6 MB/s  eta 0:00:01
# Collecting toolz<0.13.0,>=0.11.0
#   Downloading toolz-0.12.0-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 8.4 MB/s  eta 0:00:01
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/site-packages (from altair<5.0.0,>=4.0.0->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (0.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/site-packages (from altair<5.0.0,>=4.0.0->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (3.0.3)
# Collecting jaraco.functools
#   Downloading jaraco.functools-3.6.0-py3-none-any.whl (7.9 kB)
# Collecting more-itertools>=2.6
#   Downloading more_itertools-9.1.0-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 5.8 MB/s  eta 0:00:01
# Collecting wrapt<2,>=1.10
#   Downloading wrapt-1.15.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (78 kB)
#      |████████████████████████████████| 78 kB 15.7 MB/s eta 0:00:01
# Collecting orderedmultidict>=1.0.1
#   Downloading orderedmultidict-1.0.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/site-packages (from glom<24.0.0,>=22.1.0->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (21.2.0)
# Collecting face==20.1.1
#   Downloading face-20.1.1-py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 15.4 MB/s eta 0:00:01
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/site-packages (from ipynbname<2022.0.0,>=2021.3.2->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (6.13.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/site-packages (from jsonschema<5.0.0,>=3.2.0->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (0.18.0)
# Requirement already satisfied: pygments>=2.4.1 in /usr/local/lib/python3.10/site-packages (from nbconvert>=5.6.1->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (2.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/site-packages (from nbconvert>=5.6.1->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (1.5.0)
# Requirement already satisfied: nbformat>=4.4 in /usr/local/lib/python3.10/site-packages (from nbconvert>=5.6.1->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (5.1.3)
# Requirement already satisfied: traitlets>=5.0 in /usr/local/lib/python3.10/site-packages (from nbconvert>=5.6.1->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (5.1.1)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.10/site-packages (from nbconvert>=5.6.1->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (4.9.1)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/site-packages (from nbconvert>=5.6.1->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/site-packages (from nbconvert>=5.6.1->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (0.2.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/site-packages (from nbconvert>=5.6.1->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (4.1.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/site-packages (from nbconvert>=5.6.1->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (0.8.4)
# Requirement already satisfied: testpath in /usr/local/lib/python3.10/site-packages (from nbconvert>=5.6.1->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (0.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /usr/local/lib/python3.10/site-packages (from nbconvert>=5.6.1->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (0.5.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/site-packages (from jinja2->altair<5.0.0,>=4.0.0->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (2.0.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=5.6.1->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (1.5.6)
# Requirement already satisfied: jupyter-client>=6.1.5 in /usr/local/lib/python3.10/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=5.6.1->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (6.1.12)
# Requirement already satisfied: tornado>=4.1 in /usr/local/lib/python3.10/site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert>=5.6.1->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (6.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.10/site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert>=5.6.1->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (22.3.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/site-packages (from nbformat>=4.4->nbconvert>=5.6.1->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (0.2.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/site-packages (from pandas>=1.0.1->polly-python==0.3.1-fetch-quilt-metadata) (2021.3)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.2.2-py3-none-any.whl (24 kB)
# Collecting backoff>=1.10.0
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Collecting monotonic>=1.5
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting pluggy<2.0,>=0.12
#   Downloading pluggy-1.0.0-py2.py3-none-any.whl (13 kB)
# Collecting tomli>=1.0.0
#   Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Collecting exceptiongroup>=1.0.0rc8
#   Downloading exceptiongroup-1.1.1-py3-none-any.whl (14 kB)
# Collecting iniconfig
#   Downloading iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Requirement already satisfied: rsa in /usr/local/lib/python3.10/site-packages (from python-jose>=3.3.0->polly-python==0.3.1-fetch-quilt-metadata) (4.7.2)
# Collecting ecdsa!=0.15
#   Downloading ecdsa-0.18.0-py2.py3-none-any.whl (142 kB)
#      |████████████████████████████████| 142 kB 77.9 MB/s eta 0:00:01
# Requirement already satisfied: pyasn1 in /usr/local/lib/python3.10/site-packages (from python-jose>=3.3.0->polly-python==0.3.1-fetch-quilt-metadata) (0.4.8)
# Requirement already satisfied: docutils>=0.11 in /usr/local/lib/python3.10/site-packages (from rst2txt>=1.1.0->polly-python==0.3.1-fetch-quilt-metadata) (0.15.2)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.4.1-py3-none-any.whl (36 kB)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/site-packages (from bleach->nbconvert>=5.6.1->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (0.5.1)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.10/site-packages (from ipykernel->ipynbname<2022.0.0,>=2021.3.2->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (1.6.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/site-packages (from ipykernel->ipynbname<2022.0.0,>=2021.3.2->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (5.9.4)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.10/site-packages (from ipykernel->ipynbname<2022.0.0,>=2021.3.2->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (0.1.3)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.10/site-packages (from ipykernel->ipynbname<2022.0.0,>=2021.3.2->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (8.2.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->ipynbname<2022.0.0,>=2021.3.2->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (5.1.0)
# Requirement already satisfied: stack-data in /usr/local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->ipynbname<2022.0.0,>=2021.3.2->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (0.6.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->ipynbname<2022.0.0,>=2021.3.2->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (3.0.22)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->ipynbname<2022.0.0,>=2021.3.2->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (58.1.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->ipynbname<2022.0.0,>=2021.3.2->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->ipynbname<2022.0.0,>=2021.3.2->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->ipynbname<2022.0.0,>=2021.3.2->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->ipynbname<2022.0.0,>=2021.3.2->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (0.18.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->ipynbname<2022.0.0,>=2021.3.2->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (0.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->ipynbname<2022.0.0,>=2021.3.2->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel->ipynbname<2022.0.0,>=2021.3.2->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (0.2.5)
# Requirement already satisfied: networkx<4.0,>=2.3 in /usr/local/lib/python3.10/site-packages (from pronto->polly-validator==0.0.1->polly-python==0.3.1-fetch-quilt-metadata) (3.0)
# Collecting pronto
#   Downloading pronto-2.5.3-py2.py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 14.6 MB/s eta 0:00:01
# Collecting networkx~=2.3
#   Downloading networkx-2.8.8-py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 47.1 MB/s eta 0:00:01
# Collecting pronto
#   Downloading pronto-2.5.2-py2.py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 17.2 MB/s eta 0:00:01
#   Downloading pronto-2.5.1-py2.py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 15.9 MB/s eta 0:00:01
# Collecting fastobo~=0.12.1
#   Downloading fastobo-0.12.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 49.0 MB/s eta 0:00:01
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->ipynbname<2022.0.0,>=2021.3.2->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->ipynbname<2022.0.0,>=2021.3.2->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (2.2.1)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->ipynbname<2022.0.0,>=2021.3.2->datapane>=0.9.1->polly-python==0.3.1-fetch-quilt-metadata) (0.2.2)
# Using legacy 'setup.py install' for micawber, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for pyngrok, since package 'wheel' is not installed.
# Installing collected packages: more-itertools, boltons, typing-extensions, toolz, requests, orderedmultidict, networkx, monotonic, jarowinkler, jaraco.functools, fastobo, face, backoff, wrapt, vega-datasets, tomli, tenacity, tabulate, soupsieve, requests-toolbelt, rapidfuzz, pyngrok, pydantic, pyarrow, pronto, posthog, pluggy, multimethod, micawber, lxml, ipynbname, iniconfig, importlib-resources, h5py, glom, furl, exceptiongroup, ecdsa, dulwich, dominate, datacommons-pandas, datacommons, dacite, colorlog, click-spinner, click, cheroot, appdirs, altair, rst2txt, retrying, python-jose, pytest, polly-validator, plotly, mixpanel, joblib, elucidatacmapPy, elucidatacloudpathlib, Deprecated, datapane, cryptography, beautifulsoup4, polly-python
#     Running setup.py install for pyngrok ... done
#     Running setup.py install for micawber ... done
# Successfully installed Deprecated-1.2.13 altair-4.2.2 appdirs-1.4.4 backoff-2.2.1 beautifulsoup4-4.12.2 boltons-21.0.0 cheroot-9.0.0 click-8.1.3 click-spinner-0.1.10 colorlog-6.7.0 cryptography-40.0.2 dacite-1.8.0 datacommons-1.4.3 datacommons-pandas-0.0.3 datapane-0.16.4 dominate-2.7.0 dulwich-0.21.3 ecdsa-0.18.0 elucidatacloudpathlib-0.6.6 elucidatacmapPy-3.3.4 exceptiongroup-1.1.1 face-20.1.1 fastobo-0.12.2 furl-2.1.3 glom-23.3.0 h5py-3.8.0 importlib-resources-5.12.0 iniconfig-2.0.0 ipynbname-2021.3.2 jaraco.functools-3.6.0 jarowinkler-1.0.5 joblib-1.2.0 lxml-4.9.2 micawber-0.5.4 mixpanel-4.10.0 monotonic-1.6 more-itertools-9.1.0 multimethod-1.9.1 networkx-2.8.8 orderedmultidict-1.0.1 plotly-5.14.1 pluggy-1.0.0 polly-python-0.3.1 polly-validator-0.0.1 posthog-2.5.0 pronto-2.5.1 pyarrow-10.0.1 pydantic-1.10.7 pyngrok-5.2.3 pytest-7.3.1 python-jose-3.3.0 rapidfuzz-2.1.1 requests-2.25.1 requests-toolbelt-0.10.1 retrying-1.3.4 rst2txt-1.1.0 soupsieve-2.4.1 tabulate-0.8.10 tenacity-8.2.2 tomli-2.0.1 toolz-0.12.0 typing-extensions-4.5.0 vega-datasets-0.9.0 wrapt-1.15.0
# WARNING: You are using pip version 21.2.4; however, version 23.1 is available.
# You should consider upgrading via the '/usr/local/bin/python3.10 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from polly.auth import Polly
from polly.omixatlas import OmixAtlas
TEST_TOKEN = "eyJjdHkiOiJKV1QiLCJlbmMiOiJBMjU2R0NNIiwiYWxnIjoiUlNBLU9BRVAifQ.H3zAa_ipEV8AVZlIxKDEfCY0MiXb2K4Wv5Xl6sLnX5gCzAmaskK6kZg8mlKFdcmnQL7ydke6HpAvGvUvOnw8Yp6PxEWqL6gsMFBOohqa4PihcVuj-EM0xHGy1CQXrsrG9dzTZF9WAu71qUb3Bbo66oPLV_SwcFWQkYx3F9LS9ZXFDjJrVgPRsJ_ca_lW4BpnnHhTTfbxeubwFC2eI2jpUCXwdGgORr2AZVTA5ZRSou3rIBuNFqOVi0iU3JiOa98snPOyoumKZ-dSOvtKIVixeJwz1wYudMci30gaw2J5ZsqSp2hjgrICsUHt62MNrLvSqpKYutq_-9TjS3bRt1w70Q.QZcIjR7qzbxbR8gI.sr9bPSzXZ95IUM9KnnprRV_Vr6yCvxD8bqCrt73PG8617zp_9HFzpE7UFkQQ8q7L2sLWf_IUBsABlRr-khTtqkdWgvQnDR_SjYXcrQufABO2AjMD-nXb3lLsQdN77Lgi06ApDp3YoRo5RACKHFxrFGOSQfLnn3hqzAXRpZntCQP1ia0iXK3yR6QiL_yqeusgLVyUZHFX9FeBFuv6NiDq9F2r3cOvBcgz8cPfqSw4h_KG4FAAa1UGZHwZYjxJ26csOhqYVTSffUOrrd1fRMXP2k0rMgCUFiHyTIClodn2lu4EWYtIWo4jARufl9UdNj3U1aq7wnX0RW-GhaKC6P_2iQSX7ISuG5-FuIPB-Ya38Qn0iI9EGUG6vAqVxjxwRGrgIhAm8Qh4oucTuEd4qaf-76dq6aNWU8CdzLka-JOjeIVMsltBwzfey-N-2CazJvcyslWUtlbPviZ32iVEBLqxtDP5bOK-iVjEUr3eovOnKMLQiocsfSqKc3yoSpHqi4u6NglNRMD4e7WXcWEPtFbiJM0HiJs3FDLc7j0mxMC6zHilKOWqRoEot7V_7rGhxYHeGDcVw3wIGC2XxYa79zZoDLkxVP2H_JGrgxTMqorXjVufH0DQ_aX48l5LiY4W2FOM2dyutlrCckuSJPOpfDPrXM992UWuz2ust1TwGZ__zm0uuILtCRuXCyjISrOX1FRQ7lorXA5e1YVLY_c69YAmTlUZPi10I28zsq6B6rS91bNuRJu1VFTjRIbmuURKKq67zLYWCuKY2jwWOjkeCqriQuUsXG4nJlWc2Jy4lPD1zDhYOjrdsNiKq2CZPPJ0rSK9lBYICbi-HHfox-IDeahBPfD_qnnrHthUttSywHNMYYeIpdIMerbmEXg7w9QFLPrZ2UAb_LPJdIt1yRaaT21ytrEmVHyc9T6DmRsWOAH4-2RiWVgC_j_ij1GpPONIL0Z6juBuoZb4ChWeeUkxhg0ZpZupHZLO56dRDRfunzHuTPMgXUGXH316QxvV6O87QQ2wAW6UwzaA35zLZJWgt8jTkOYYt4ZzKodJ8I6pJV4kU-oKVs6Nx6O7oUJMps8f5z4v2FAxbLRSA-sDvi2HKdlI96KDxGrtd0S8Z4vNxIKnYZ_lZmvOVW6ei9fs0wEOS_jErcmrbxMZlAyKJFH8WXA0-Z78MB2d9k6V8s9_nwKzPUKAnXfjFlEDP3lXbcYf4h-FWIn511BSKMppxXqgcspY0A3twrY5lh-0SNaCeGwE2FyuHNcQUUMY-Px6HWTyEihPKB1E3qaj0sDQuynd9F6gQPxBzAPzl_V3VIiud2pKaJzcOpxOFOuCJU3bGwQPUnV5G4BPeCizWH58.jbAqMVog--xRqpE4Jja24A"
Polly.auth(TEST_TOKEN,"testpolly")
omix = OmixAtlas()

# %%
omix.omixatlas_summary("1643016586529")
# Out:
# {'data': {'repo_name': 'geo',
#   'repo_id': '1643016586529',
#   'indexes': {'files': 'geo_files',
#    'joint': 'geo_joint',
#    'gct_col_metadata': 'geo_gct_col_metadata'},
#   'v2_indexes': {'files': 'geo_files',
#    'joint': 'geo_joint',
#    'gct_col_metadata': 'geo_gct_col_metadata'},
#   'linked_workspace_id': '15196',
#   'sources': [{'geo': 7}, {'source': 1}, {'vfv': 1}],
#   'datatypes': [{'transcriptomics': 9}],
#   'dataset_count': 9,
#   'disease_count': 17,
#   'tissue_count': 10,
#   'organism_count': 2,
#   'cell_line_count': 5,
#   'cell_type_count': 6,
#   'drug_count': 2,
#   'data_type_count': 1,
#   'data_source_count': 3,
#   'sample_count': 1792.0,
#   'normal_sample_count': 154446}}

# %%
df = omix._fetch_quilt_metadata("geo","GSE107990_GPL10558")
# Out:
# The dataset level metadata for dataset = GSE107990_GPL10558 has been downloaded at : = /tmp/tmp_hfx0gsu/GSE107990_GPL10558.json

# %%
df
# Out:
# {'disease': ['Influenza, Human', 'Acquired Immunodeficiency Syndrome'],
#  'kw_strain': ['None'],
#  'organism': ['Homo sapiens'],
#  'curation_version': '2023_02_02',
#  'total_num_samples': 671,
#  'kw_drug': ['prednisone'],
#  'dataset_id': 'GSE107990_GPL10558',
#  'description': 'Gene expression profiles associated with humoral response to influenza vaccine, Vaxigrip, in young and elderly subjects of Chinese ethnicity in Singapore',
#  'kw_cell_line': ['None'],
#  'tissue': ['None'],
#  'manually_curated_fields': {'dataset_level': [],
#   'sample_level': ['curated_cohort_name']},
#  'platform': 'unknown_platform',
#  'file_type': 'h5ad',
#  'dataset_source': 'GEO',
#  'source_process': 'connector',
#  'kw_smiles': ['[H][C@@]12CCC3=CC(=O)C=C[C@]3(C)[C@@]1([H])C(=O)C[C@@]1(C)[C@@]2([H])CC[C@]1(O)C(=O)CO'],
#  '__index__': {'file_metadata': 'true',
#   'col_metadata': 'true',
#   'data_required': 'false',
#   'pushed_through': 'Curation App - job_id=a4333eae-fe7d-4566-aa70-dcb346984dec',
#   'pushed_at': '2023-04-03T06:12:58',
#   'row_metadata': 'false'},
#  'kw_data_type': 'Transcriptomics',
#  'kw_cell_type': ['None']}

# %%
# case for wrong repo_key/repo_id
df = omix._fetch_quilt_metadata("vivek","GSE107990_GPL10558")
# Out:
# ---------------------------------------------------------------------------
# RequestException                          Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 df = omix._fetch_quilt_metadata("vivek","GSE107990_GPL10558")
#
# File ~/.local/lib/python3.10/site-packages/polly/tracking.py:48, in Track.track_decorator.<locals>.wrapper_function(*args, **kwargs)
#      46         return result
#      47 else:
# ---> 48     raise returned_err
#
# File ~/.local/lib/python3.10/site-packages/polly/tracking.py:20, in Track.track_decorator.<locals>.wrapper_function(*args, **kwargs)
#      18 execution_flag = False
#      19 try:
# ---> 20     result = function(*args, **kwargs)
#      21     execution_flag = True
#      22 except Exception as e:
#
# File ~/.local/lib/python3.10/site-packages/polly/omixatlas.py:4385, in OmixAtlas._fetch_quilt_metadata(self, repo_key, dataset_id)
#    4373 """
#    4374 This function is used to get the quilt sample level metadata as a dataframe.
#    4375 Args:
#    (...)
#    4382     Quilt metadata in json format is returned.
#    4383 """
#    4384 omix_hlpr.check_params_for_fetch_quilt_metadata(repo_key, dataset_id)
# -> 4385 repo_summary = self.omixatlas_summary(repo_key)
#    4386 repo_id = repo_summary.get("data", "").get("repo_id")  # Extracting repo_id
#    4387 # getting dataset level metadata using download_metadata function
#
# File ~/.local/lib/python3.10/site-packages/polly/tracking.py:48, in Track.track_decorator.<locals>.wrapper_function(*args, **kwargs)
#      46         return result
#      47 else:
# ---> 48     raise returned_err
#
# File ~/.local/lib/python3.10/site-packages/polly/tracking.py:20, in Track.track_decorator.<locals>.wrapper_function(*args, **kwargs)
#      18 execution_flag = False
#      19 try:
# ---> 20     result = function(*args, **kwargs)
#      21     execution_flag = True
#      22 except Exception as e:
#
# File ~/.local/lib/python3.10/site-packages/polly/omixatlas.py:204, in OmixAtlas.omixatlas_summary(self, repo_key, query_api_version, count_by_source, count_by_data_type)
#     202 if params:
#     203     response = self.session.get(url, params=params)
# --> 204 error_handler(response)
#     205 return response.json()
#
# File ~/.local/lib/python3.10/site-packages/polly/errors.py:337, in error_handler(response)
#     335     if title == app_err_info.REPOSITORY_LOCKED:
#     336         detail = app_err_info.REPOSITORY_LOCKED_DETAIL
# --> 337     raise RequestException(title, detail)
#     338 elif response.status_code == 401:
#     339     raise UnauthorizedException
#
# RequestException: ("No repository for identifier 'vivek'", 'Requested resource does not exist')

# %%
# case for wrong dataset_id
df = omix._fetch_quilt_metadata("geo","GSE107990_GPL1055")
# Out:
# ---------------------------------------------------------------------------
# paramException                            Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 df = omix._fetch_quilt_metadata("geo","GSE107990_GPL1055")
#
# File ~/.local/lib/python3.10/site-packages/polly/tracking.py:48, in Track.track_decorator.<locals>.wrapper_function(*args, **kwargs)
#      46         return result
#      47 else:
# ---> 48     raise returned_err
#
# File ~/.local/lib/python3.10/site-packages/polly/tracking.py:20, in Track.track_decorator.<locals>.wrapper_function(*args, **kwargs)
#      18 execution_flag = False
#      19 try:
# ---> 20     result = function(*args, **kwargs)
#      21     execution_flag = True
#      22 except Exception as e:
#
# File ~/.local/lib/python3.10/site-packages/polly/omixatlas.py:4389, in OmixAtlas._fetch_quilt_metadata(self, repo_key, dataset_id)
#    4387 # getting dataset level metadata using download_metadata function
#    4388 with TempDir() as dir_path:
# -> 4389     self.download_metadata(repo_id, dataset_id, dir_path)
#    4390     filepath = os.path.join(dir_path, f"{dataset_id}.json")
#    4391     metadata = helpers.read_json(filepath)
#
# File ~/.local/lib/python3.10/site-packages/polly/tracking.py:48, in Track.track_decorator.<locals>.wrapper_function(*args, **kwargs)
#      46         return result
#      47 else:
# ---> 48     raise returned_err
#
# File ~/.local/lib/python3.10/site-packages/polly/tracking.py:20, in Track.track_decorator.<locals>.wrapper_function(*args, **kwargs)
#      18 execution_flag = False
#      19 try:
# ---> 20     result = function(*args, **kwargs)
#      21     execution_flag = True
#      22 except Exception as e:
#
# File ~/.local/lib/python3.10/site-packages/polly/omixatlas.py:4081, in OmixAtlas.download_metadata(self, repo_key, dataset_id, file_path, metadata_key)
#    4079 elastic_url = f"{self.elastic_url}/{index_name}/_search"
#    4080 query = helpers.elastic_query(index_name, dataset_id)
# -> 4081 metadata = helpers.get_metadata(self, elastic_url, query)
#    4082 source_info = metadata.get("_source")
#    4083 file_name = f"{dataset_id}.json"
#
# File ~/.local/lib/python3.10/site-packages/polly/helpers.py:319, in get_metadata(self, url, payload)
#     317 hits = response_data.get("hits", {}).get("hits")
#     318 if not (hits and isinstance(hits, list)):
# --> 319     raise paramException(
#     320         title="Param Error",
#     321         detail="No matches found with the given repo details. Please try again.",
#     322     )
#     323 dataset = hits[0]
#     324 return dataset
#
# paramException: paramException (parameter error): No matches found with the given repo details. Please try again.
